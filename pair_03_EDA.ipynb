# %% [markdown]
# # Ejercicios de exploración del conjunto de datos

# %%
import pandas as pd

# %%
df_world = pd.read_csv('world-data-2023_part1.csv')

# %% [markdown]
# 1. Muestra las primeras 5 filas del conjunto de datos.

# %%
df_world.head(5)
# Out:
#    Unnamed: 0      Country Density\n(P/Km2) Abbreviation  \
# 0           0  Afghanistan               60           AF
# 1           1      Albania              105           AL
# 2           2      Algeria               18           DZ
# 3           3      Andorra              164           AD
# 4           4       Angola               26           AO
#
#   Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 0                58.10%        652,230           323,000       32.49
# 1                43.10%         28,748             9,000       11.78
# 2                17.40%      2,381,741           317,000       24.28
# 3                40.00%            468               NaN        7.20
# 4                47.50%      1,246,700           117,000       40.73
#
#    Calling Code Capital/Major City Co2-Emissions     CPI CPI Change (%)  \
# 0          93.0              Kabul         8,672   149.9          2.30%
# ...

# %% [markdown]
# 2. Muestra las últimas 5 filas del conjunto de datos.

# %%
df_world.tail(5)
# Out:
#      Unnamed: 0    Country Density\n(P/Km2) Abbreviation  \
# 190         190  Venezuela               32           VE
# 191         191    Vietnam              314           VN
# 192         192      Yemen               56           YE
# 193         193     Zambia               25           ZM
# 194         194   Zimbabwe               38           ZW
#
#     Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 190                24.50%        912,050           343,000       17.88
# 191                39.30%        331,210           522,000       16.75
# 192                44.60%        527,968            40,000       30.45
# 193                32.10%        752,618            16,000       36.19
# 194                41.90%        390,757            51,000       30.68
#
#      Calling Code Capital/Major City Co2-Emissions       CPI CPI Change (%)  \
# 190          58.0            Caracas       164,175  2,740.27        254.90%
# ...

# %% [markdown]
# 3. Muestra una muestra aleatoria de 5 filas del conjunto de datos.

# %%
df_world.sample(5)
# Out:
#      Unnamed: 0                Country Density\n(P/Km2) Abbreviation  \
# 114         114               Mongolia                2           MN
# 39           39  Republic of the Congo               16          NaN
# 116         116                Morocco               83           MA
# 138         138            Philippines              368           PH
# 82           82                 Israel              400           IL
#
#     Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 114                71.50%      1,564,116            18,000       24.13
# 39                 31.10%        342,000            12,000       32.86
# 116                68.50%        446,550           246,000       18.94
# 138                41.70%        300,000           153,000       20.55
# 82                 24.60%         20,770           178,000       20.80
#
#      Calling Code Capital/Major City Co2-Emissions     CPI CPI Change (%)  \
# ...

# %% [markdown]
# 4. Muestra el nombre de todas las columnas en el conjunto de datos.

# %%
df_world.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Density\n(P/Km2)', 'Abbreviation',
#        'Agricultural Land( %)', 'Land Area(Km2)', 'Armed Forces size',
#        'Birth Rate', 'Calling Code', 'Capital/Major City', 'Co2-Emissions',
#        'CPI', 'CPI Change (%)', 'Currency-Code', 'Fertility Rate',
#        'Forested Area (%)', 'Gasoline Price'],
#       dtype='object')

# %% [markdown]
# 5. Muestra los valores únicos en la columna "Abbreviation".

# %%
df_world['Abbreviation'].unique()
# Out:
# array(['AF', 'AL', 'DZ', 'AD', 'AO', 'AG', 'AR', 'AM', 'AU', 'AT', 'AZ',
#        'BS', 'BH', 'BD', 'BB', 'BY', 'BE', 'BZ', 'BJ', 'BT', 'BO', 'BA',
#        'BW', 'BR', 'BN', 'BG', 'BF', 'BI', 'CI', 'CV', 'KH', 'CM', 'CA',
#        'CF', 'TD', 'CL', 'CN', 'CO', 'KM', nan, 'CR', 'HR', 'CU', 'CY',
#        'CZ', 'CD', 'DK', 'DJ', 'DM', 'DO', 'EC', 'EG', 'SV', 'GQ', 'ER',
#        'EE', 'ET', 'FJ', 'FI', 'FR', 'GA', 'GM', 'GE', 'DE', 'GH', 'GR',
#        'GD', 'GT', 'GN', 'GW', 'GY', 'HT', 'HN', 'HU', 'IS', 'IN', 'ID',
#        'IR', 'IQ', 'IL', 'IT', 'JM', 'JP', 'JO', 'KZ', 'KE', 'KI', 'KW',
#        'KG', 'LA', 'LV', 'LB', 'LS', 'LR', 'LY', 'LI', 'LT', 'LU', 'MG',
#        'MW', 'MY', 'MV', 'ML', 'MT', 'MH', 'MR', 'MU', 'MX', 'FM', 'MD',
#        'MC', 'MN', 'ME', 'MA', 'MZ', 'MM', 'NR', 'NP', 'NL', 'NZ', 'NI',
#        'NE', 'NG', 'KP', 'NO', 'OM', 'PK', 'PW', 'PA', 'PG', 'PY', 'PE',
#        'PH', 'PL', 'PT', 'QA', 'RO', 'RU', 'RW', 'KN', 'LC', 'VC', 'WS',
# ...

# %% [markdown]
# 6. Cuenta cuántas veces aparece cada valor único en la columna "Abbreviation".

# %%
df_world['Abbreviation'].value_counts()
# Out:
# Abbreviation
# AF    1
# PY    1
# NE    1
# NG    1
# KP    1
#      ..
# GR    1
# GD    1
# GT    1
# GN    1
# ZW    1
# Name: count, Length: 188, dtype: int64

# %% [markdown]
# 7. Verifica si hay valores nulos en el conjunto de datos.

# %%
df_world.isnull() #sale el df en tabla con todos lo false
df_world.isnull().sum() #sale agrupado por la suma de nulls
# Out:
# Unnamed: 0                0
# Country                   0
# Density\n(P/Km2)          0
# Abbreviation              7
# Agricultural Land( %)     7
# Land Area(Km2)            1
# Armed Forces size        24
# Birth Rate                6
# Calling Code              1
# Capital/Major City        3
# Co2-Emissions             7
# CPI                      17
# CPI Change (%)           16
# Currency-Code            15
# Fertility Rate            7
# Forested Area (%)         7
# Gasoline Price           20
# dtype: int64

# %% [markdown]
# 8. Verifica si hay valores no nulos en el conjunto de datos.

# %%
df_world.notnull().sum() #igual que el de arriba, si queremos visualizarlo en vez de sumar es sin .sum()
# Out:
# Unnamed: 0               195
# Country                  195
# Density\n(P/Km2)         195
# Abbreviation             188
# Agricultural Land( %)    188
# Land Area(Km2)           194
# Armed Forces size        171
# Birth Rate               189
# Calling Code             194
# Capital/Major City       192
# Co2-Emissions            188
# CPI                      178
# CPI Change (%)           179
# Currency-Code            180
# Fertility Rate           188
# Forested Area (%)        188
# Gasoline Price           175
# dtype: int64

# %% [markdown]
# 9. Muestra información general sobre el conjunto de datos.

# %%
df_world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             195 non-null    int64
#  1   Country                195 non-null    object
#  2   Density
# (P/Km2)        195 non-null    object
#  3   Abbreviation           188 non-null    object
#  4   Agricultural Land( %)  188 non-null    object
#  5   Land Area(Km2)         194 non-null    object
#  6   Armed Forces size      171 non-null    object
#  7   Birth Rate             189 non-null    float64
#  8   Calling Code           194 non-null    float64
#  9   Capital/Major City     192 non-null    object
#  10  Co2-Emissions          188 non-null    object
#  11  CPI                    178 non-null    object
#  12  CPI Change (%)         179 non-null    object
#  13  Currency-Code          180 non-null    object
# ...

# %% [markdown]
# 10. Elimina una columna específica (por ejemplo, "Armed Forces size").

# %%
df_limpio = df_world.drop(columns=['Armed Forces size'])
df_limpio
# Out:
#      Unnamed: 0      Country Density\n(P/Km2) Abbreviation  \
# 0             0  Afghanistan               60           AF
# 1             1      Albania              105           AL
# 2             2      Algeria               18           DZ
# 3             3      Andorra              164           AD
# 4             4       Angola               26           AO
# ..          ...          ...              ...          ...
# 190         190    Venezuela               32           VE
# 191         191      Vietnam              314           VN
# 192         192        Yemen               56           YE
# 193         193       Zambia               25           ZM
# 194         194     Zimbabwe               38           ZW
#
#     Agricultural Land( %) Land Area(Km2)  Birth Rate  Calling Code  \
# 0                  58.10%        652,230       32.49          93.0
# 1                  43.10%         28,748       11.78         355.0
# ...

# %% [markdown]
# 11. Selecciona las columnas numéricas del conjunto de datos y muestra sus estadísticas descriptivas básicas (para esto tendréis que usar el método '.describe(), su documentación la tenéis aquí).

# %%
colum_num = df_world.select_dtypes(include=['float64', 'int64'])
colum_num.describe()
# Out:
#        Unnamed: 0  Birth Rate  Calling Code  Fertility Rate
# count  195.000000  189.000000    194.000000      188.000000
# mean    97.000000   20.214974    360.546392        2.698138
# std     56.435804    9.945774    323.236419        1.282267
# min      0.000000    5.900000      1.000000        0.980000
# 25%     48.500000   11.300000     82.500000        1.705000
# 50%     97.000000   17.950000    255.500000        2.245000
# 75%    145.500000   28.750000    506.750000        3.597500
# max    194.000000   46.080000   1876.000000        6.910000
